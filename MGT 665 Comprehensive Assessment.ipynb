# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("weight-height.csv") ## loading dataset

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender']) ## encoding categorical values

# %%
X = df[['Height', 'Gender']]
y = df['Weight'] ## setting x and y

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42) ## train-test split

# %%
lm = LinearRegression()
lm.fit(X_train, y_train) ## building model
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_test) ## predicting

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 101.87

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.xlim(70,270)
plt.ylim(70,270)
plt.show() ## actual vs predicted plot
